# %%
import os 
os.getcwd()
# Out:
# '/home/psenin/git/saxpy/jupyter'

# %%
os.chdir("/home/psenin/git/saxpy")
import numpy as np
from saxpy.znorm import znorm
from saxpy.discord import find_best_discord_brute_force
from saxpy.discord import find_best_discord_brute_force2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-802b63f4f92a> in <module>()
#       3 from saxpy.znorm import znorm
#       4 from saxpy.discord import find_best_discord_brute_force
# ----> 5 from saxpy.discord import find_best_discord_brute_force2
#
# ImportError: cannot import name 'find_best_discord_brute_force2'

# %%
from numpy import genfromtxt
dd = genfromtxt("data/ecg0606_1.csv", delimiter=',')

# %%
import matplotlib.pyplot as plt
plt.plot(dd)
plt.show()

# %%
discord = find_best_discord_brute_force(s, 100)
discord
# Out:
# (173, 0.74699397587932304)

# %%
discord[0]
# Out:
# 173
